# %%
import pandas as pd

mt_df = pd.read_json('/Users/lockewang/FIG/software-control/external_data/mt-mind2web/train_0.json')
mt_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 42 entries, 0 to 41
# Data columns (total 5 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   task_id    42 non-null     object
#  1   website    42 non-null     object
#  2   domain     42 non-null     object
#  3   subdomain  42 non-null     object
#  4   turns      42 non-null     object
# dtypes: object(5)
# memory usage: 1.8+ KB

# %%
mt_df.head(1)
# Out:
#                                 task_id   website  domain subdomain  \
# 0  4a72bd8a-a4a4-4e8f-afaf-9cb100329e06  spothero  Travel     Other
#
#                                                turns
# 0  [{'annotation_id': 'aa83d501-a873-41b2-8565-a6...

# %%
from pprint import pprint

pprint(mt_df['turns'][0][0]['annotation_id'])
pprint(mt_df['turns'][0][0]['confirmed_task'])
pprint(mt_df['turns'][0][0]['action_reprs'])
# Out:
# 'aa83d501-a873-41b2-8565-a628a7b777e9'
# ('Find wheelchair accessible parking for april 09 event in barclays center '
#  'that allows entry after 10am.')
# ['[textbox]  Search for parking -> TYPE: Barclays Center',
#  '[li]  Barclays Center, Atlantic Avenue, Brooklyn, NY, US... -> CLICK',
#  '[textbox]  Select Event Date -> CLICK',
#  '[gridcell]  Sun Apr 09 2023 -> CLICK',
#  '[p]  Philadelphia 76ers at Brooklyn Nets -> CLICK',
#  '[button]  Filter -> CLICK',
#  '[checkbox]  Wheelchair Accessible (18) -> CLICK',
#  '[button]  Show 18 Results -> CLICK',
#  '[combobox]  Start Time -> SELECT: 10:00 AM',
#  '[button]  Update Search -> CLICK']

# %%
pprint(mt_df['turns'][0][0]['actions'])
# Out:
# [{'action_uid': 'b856c4ca-c796-45be-9390-70f6957a0bc0',
#   'cleaned_html': '<html backend_node_id="131">\n'
#                   '  <body backend_node_id="368">\n'
#                   '    <div backend_node_id="369">\n'
#                   '      <header backend_node_id="370" role="banner">\n'
#                   '        <div backend_node_id="371">\n'
#                   '          <a backend_node_id="373" aria_label="Home"/>\n'
#                   '          <nav backend_node_id="376" role="navigation">\n'
#                   '            <ul backend_node_id="377" role="list">\n'
#                   '              <li backend_node_id="378">\n'
#                   '                <div backend_node_id="379">\n'
#                   '                  <p backend_node_id="380">\n'
#                   '                    <text '
#                   'backend_node_id="381">About</text>\n'
#                   '                  </p>\n'
# ...
